# %% [markdown]
# # Map, Filter y Reduce en Python
#
# Vamos a hacer algunos ejemplos para entender como estos metodos hacen sinergia entre si para un procesamiento de datos con enfoque funcional.

# %%
import pandas as pd
import numpy as np
from functools import reduce

# %%
# Cargar el dataset
df = pd.read_csv('datasets/global-missing-migrants-dataset.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13020 entries, 0 to 13019
# Data columns (total 19 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Incident Type                        13020 non-null  object
#  1   Incident year                        13020 non-null  int64
#  2   Reported Month                       13020 non-null  object
#  3   Region of Origin                     12998 non-null  object
#  4   Region of Incident                   13020 non-null  object
#  5   Country of Origin                    13012 non-null  object
#  6   Number of Dead                       12470 non-null  float64
#  7   Minimum Estimated Number of Missing  13020 non-null  int64
#  8   Total Number of Dead and Missing     13020 non-null  int64
#  9   Number of Survivors                  13020 non-null  int64
#  10  Number of Females                    13020 non-null  int64
#  11  Number of Males                      13020 non-null  int64
#  12  Number of Children                   13020 non-null  int64
#  13  Cause of Death                       13020 non-null  object
#  14  Migration route                      9999 non-null   object
#  15  Location of death                    13020 non-null  object
#  16  Information Source                   13012 non-null  object
#  17  Coordinates                          12984 non-null  object
#  18  UNSD Geographical Grouping           13019 non-null  object
# dtypes: float64(1), int64(7), object(11)
# memory usage: 1.9+ MB

# %% [markdown]
# ## Map
#
# Vamos a usar map para convertir todos los nombres de las regiones a minúsculas

# %%
df['Region of Origin'].head(5)
# Out:
# 0                  central america
# 1    latin america / caribbean (p)
# 2    latin america / caribbean (p)
# 3                  central america
# 4                  northern africa
# Name: Region of Origin, dtype: object

# %%
df['Region of Origin'] = df['Region of Origin'].astype(str).map(lambda x: x.lower())

# %%
df['Region of Origin'].head(5)
# Out:
# 0                  central america
# 1    latin america / caribbean (p)
# 2    latin america / caribbean (p)
# 3                  central america
# 4                  northern africa
# Name: Region of Origin, dtype: object

# %% [markdown]
# Tambien podemos usar map() para crear una columna en base a otra. Por ejemplo, vamos a crear una columna nueva que indique si hubo niños involucrados en el incidente. La unica columna que nos puede dar informacion sobre esto es 'Number Of Children' asi que vamos a usarla

# %%
def has_children(x):
    if x == 0:
        return 'no'
    else:
        return 'si'

df['Hubo niños'] = df['Number of Children'].astype(int).map(has_children)
df.head(10)
# Out:
#   Incident Type  Incident year Reported Month               Region of Origin  \
# 0      Incident           2014        January                central america
# 1      Incident           2014        January  latin america / caribbean (p)
# 2      Incident           2014        January  latin america / caribbean (p)
# 3      Incident           2014        January                central america
# 4      Incident           2014        January                northern africa
# 5      Incident           2014        January  latin america / caribbean (p)
# 6      Incident           2014        January                        unknown
# 7      Incident           2014        January  latin america / caribbean (p)
# 8      Incident           2014        January  latin america / caribbean (p)
# 9      Incident           2014        January  latin america / caribbean (p)
#
#   Region of Incident                 Country of Origin  Number of Dead  \
# 0      North America                         Guatemala             1.0
# 1      North America                           Unknown             1.0
# 2      North America                           Unknown             1.0
# 3      North America                            Mexico             1.0
# 4             Europe                             Sudan             1.0
# 5      North America                           Unknown             1.0
# 6      Mediterranean  Afghanistan,Syrian Arab Republic            12.0
# 7      North America                           Unknown             1.0
# 8      North America                           Unknown             1.0
# 9      North America                           Unknown             1.0
#
#    Minimum Estimated Number of Missing  Total Number of Dead and Missing  \
# 0                                    0                                 1
# 1                                    0                                 1
# 2                                    0                                 1
# 3                                    0                                 1
# 4                                    0                                 1
# 5                                    0                                 1
# 6                                    0                                12
# 7                                    0                                 1
# 8                                    0                                 1
# 9                                    0                                 1
#
#    Number of Survivors  Number of Females  Number of Males  \
# 0                    0                  0                1
# 1                    0                  0                0
# 2                    0                  0                0
# 3                    0                  0                1
# 4                    2                  0                1
# 5                    0                  0                0
# 6                    0                  9                0
# 7                    0                  0                0
# 8                    0                  0                0
# 9                    0                  0                0
#
#    Number of Children                                     Cause of Death  \
# 0                   0                                   Mixed or unknown
# 1                   0                                   Mixed or unknown
# 2                   0                                   Mixed or unknown
# 3                   0                                           Violence
# 4                   0  Harsh environmental conditions / lack of adequ...
# 5                   0                                           Violence
# 6                   3                                           Drowning
# 7                   0                                   Mixed or unknown
# 8                   0                                   Mixed or unknown
# 9                   0                                   Mixed or unknown
#
#              Migration route  \
# 0  US-Mexico border crossing
# 1  US-Mexico border crossing
# 2  US-Mexico border crossing
# 3  US-Mexico border crossing
# 4                        NaN
# 5  US-Mexico border crossing
# 6      Eastern Mediterranean
# 7  US-Mexico border crossing
# 8  US-Mexico border crossing
# 9  US-Mexico border crossing
#
#                                    Location of death  \
# 0  Pima Country Office of the Medical Examiner ju...
# 1  Pima Country Office of the Medical Examiner ju...
# 2  Pima Country Office of the Medical Examiner ju...
# 3                         near Douglas, Arizona, USA
# 4                  Border between Russia and Estonia
# 5  Pima Country Office of the Medical Examiner ju...
# 6  Waters near Greece while being towed back to T...
# 7  Pima Country Office of the Medical Examiner ju...
# 8  Pima Country Office of the Medical Examiner ju...
# 9  Pima Country Office of the Medical Examiner ju...
#
#                                   Information Source             Coordinates  \
# 0  Pima County Office of the Medical Examiner (PC...  31.650259, -110.366453
# 1  Pima County Office of the Medical Examiner (PC...    31.59713, -111.73756
# 2  Pima County Office of the Medical Examiner (PC...    31.94026, -113.01125
# 3  Ministry of Foreign Affairs Mexico, Pima Count...  31.506777, -109.315632
# 4                  EUBusiness (Agence France-Presse)             59.1551, 28
# 5  Pima County Office of the Medical Examiner (PC...    32.45435, -113.18402
# 6            European Council on Refugees and Exiles             37.2832, 27
# 7  Pima County Office of the Medical Examiner (PC...  32.478317, -113.182833
# 8  Pima County Office of the Medical Examiner (PC...    31.81154, -111.01101
# 9  Pima County Office of the Medical Examiner (PC...  32.174017, -112.174583
#
#   UNSD Geographical Grouping Hubo niños
# 0           Northern America         no
# 1           Northern America         no
# 2           Northern America         no
# 3           Northern America         no
# 4            Northern Europe         no
# 5           Northern America         no
# 6              Uncategorized         si
# 7           Northern America         no
# 8           Northern America         no
# 9           Northern America         no

# %% [markdown]
# ## Filter

# %% [markdown]
# Vamos a usar el metodo `filter` de Python solo para mostrar como se utilizaria en este contexto. Pandas tiene su propio metodo filter y en este caso seria mas apropiado y daria un codigo mas legible, pero como estamos aprendiendo, vamos a ver como seria.
#
# el metodo filter no acepta Dataframes de entrada, pero si acepta diccionarios, por lo que vamos a usar el metodo to_dict de DataFrame para convertirlo a diccionario y pasarselo al filtro junto con la funcion lambda para filtrar. Ademas, la salida del filtro no es un dataframe ni una lista sino un objeto Filter. Para poder recuperar la columna filtrada, tenemos que convertirla a lista primero y luego a DataFrame.

# %%
central_america_incidents = pd.DataFrame(list(filter(
    lambda row: 'central america' in row['Region of Origin'],
    df.to_dict('records')
)))
central_america_incidents.head(5)
# Out:
#   Incident Type  Incident year Reported Month Region of Origin  \
# 0      Incident           2014        January  central america
# 1      Incident           2014        January  central america
# 2      Incident           2014        January  central america
# 3      Incident           2014       February  central america
# 4      Incident           2014          March  central america
#
#   Region of Incident Country of Origin  Number of Dead  \
# 0      North America         Guatemala             1.0
# 1      North America            Mexico             1.0
# 2      North America            Mexico             1.0
# 3      North America            Mexico             1.0
# 4      North America         Guatemala             1.0
#
#    Minimum Estimated Number of Missing  Total Number of Dead and Missing  \
# 0                                    0                                 1
# 1                                    0                                 1
# 2                                    0                                 1
# 3                                    0                                 1
# 4                                    0                                 1
#
#    Number of Survivors  Number of Females  Number of Males  \
# 0                    0                  0                1
# 1                    0                  0                1
# 2                    0                  0                1
# 3                    2                  0                1
# 4                    0                  1                0
#
#    Number of Children                                     Cause of Death  \
# 0                   0                                   Mixed or unknown
# 1                   0                                           Violence
# 2                   0                                   Mixed or unknown
# 3                   0                                           Violence
# 4                   0  Harsh environmental conditions / lack of adequ...
#
#              Migration route  \
# 0  US-Mexico border crossing
# 1  US-Mexico border crossing
# 2  US-Mexico border crossing
# 3  US-Mexico border crossing
# 4  US-Mexico border crossing
#
#                                    Location of death  \
# 0  Pima Country Office of the Medical Examiner ju...
# 1                         near Douglas, Arizona, USA
# 2  Pima Country Office of the Medical Examiner ju...
# 3  California-Mexico border near San Diego, Calif...
# 4  Pima Country Office of the Medical Examiner ju...
#
#                                   Information Source             Coordinates  \
# 0  Pima County Office of the Medical Examiner (PC...  31.650259, -110.366453
# 1  Ministry of Foreign Affairs Mexico, Pima Count...  31.506777, -109.315632
# 2  Pima County Office of the Medical Examiner (PC...    32.40291, -113.02935
# 3                                                CNN           32.5543, -117
# 4  Pima County Office of the Medical Examiner (PC...      31.759, -110.51916
#
#   UNSD Geographical Grouping
# 0           Northern America
# 1           Northern America
# 2           Northern America
# 3           Northern America
# 4           Northern America

# %% [markdown]
# Vamos a ampliar nuestro filtro para que ademas incluya solamente casos desde 2014. Antes vamos a buscar si la columna Incident Year esta apta para filtrar o si necesita alguna transformacion

# %%
df['Incident year'].value_counts()
# Out:
# Incident year
# 2022    2183
# 2019    1804
# 2021    1800
# 2018    1637
# 2017    1341
# 2020    1296
# 2016    1277
# 2015     821
# 2023     565
# 2014     296
# Name: count, dtype: int64

# %% [markdown]
# El tipo de dato es el correcto y no tiene nulos, avanzamos con nuestro filtro ampliado

# %%
central_america_incidents_after_2014 = pd.DataFrame(list(filter(
    lambda row: ('central america' in row['Region of Origin']) & (row['Incident year'] > 2014), 
    df.to_dict('records')
)))
central_america_incidents_after_2014.head(5)
# Out:
#   Incident Type  Incident year Reported Month Region of Origin  \
# 0      Incident           2015        January  central america
# 1      Incident           2015        January  central america
# 2      Incident           2015        January  central america
# 3      Incident           2015       February  central america
# 4      Incident           2015       February  central america
#
#   Region of Incident Country of Origin  Number of Dead  \
# 0    Central America          Honduras             1.0
# 1    Central America          Honduras             1.0
# 2    Central America       El Salvador             1.0
# 3      North America       El Salvador             1.0
# 4    Central America          Honduras             1.0
#
#    Minimum Estimated Number of Missing  Total Number of Dead and Missing  \
# 0                                    0                                 1
# 1                                    0                                 1
# 2                                    0                                 1
# 3                                    0                                 1
# 4                                    0                                 1
#
#    Number of Survivors  Number of Females  Number of Males  \
# 0                    0                  0                1
# 1                    0                  0                1
# 2                    9                  0                1
# 3                    0                  0                0
# 4                    0                  0                1
#
#    Number of Children                                     Cause of Death  \
# 0                   0                                           Violence
# 1                   0                                           Violence
# 2                   1  Vehicle accident / death linked to hazardous t...
# 3                   0                                   Mixed or unknown
# 4                   0                                   Mixed or unknown
#
#              Migration route  \
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3  US-Mexico border crossing
# 4                        NaN
#
#                                    Location of death  \
# 0                   Gregorio Mendez, Tabasco, Mexico
# 1  Near railway tracks, Villahermosa, Tabasco, Me...
# 2            Highway out of Reforma, Tabasco, Mexico
# 3                  AP Ranch, Webb County, Texas, USA
# 4  La Cuchilla sector in municipality of Concepci...
#
#                        Information Source              Coordinates  \
# 0                                   La 72    18.056331, -93.084468
# 1                               Excelsior    17.983326, -92.916667
# 2                     Noticieros Televisa    17.875807, -93.151203
# 3  Operation Identification - U. of Texas  27.87871582, -99.142943
# 4                            Prensa Libre    14.633328, -92.133327
#
#   UNSD Geographical Grouping
# 0            Central America
# 1            Central America
# 2            Central America
# 3           Northern America
# 4            Central America

# %% [markdown]
# ## Reduce

# %% [markdown]
# Vamos a usar Reduce ahora para obtener algunas metricas. Comencemos por el numero de fallecidos totales dentro de nuestro filtro

# %%
total_dead_missing = reduce(lambda x, y: x + y, central_america_incidents['Total Number of Dead and Missing'])
print(f'Total de migrantes muertos o desaparecidos en America Central desde 2014: {total_dead_missing}')
# Out:
# Total de migrantes muertos o desaparecidos en America Central desde 2014: 2109

# %% [markdown]
# Veamos ahora el numero maximo de fallecidos en la region en un solo incidente

# %%
total_dead_missing = reduce(lambda x, y: x if x > y else y, central_america_incidents['Total Number of Dead and Missing'])
print(f'Maximo de fallecidos en un mismo incidente en America Central desde 2014: {total_dead_missing}')
# Out:
# Maximo de fallecidos en un mismo incidente en America Central desde 2014: 64

# %% [markdown]
# para ver el incidente podemos buscarlo con .loc

# %%
central_america_incidents.loc[central_america_incidents['Total Number of Dead and Missing'] == 64]
# Out:
#           Incident Type  Incident year Reported Month Region of Origin  \
# 20  Cumulative Incident           2014         August  central america
#
#    Region of Incident Country of Origin  Number of Dead  \
# 20    Central America       El Salvador            64.0
#
#     Minimum Estimated Number of Missing  Total Number of Dead and Missing  \
# 20                                    0                                64
#
#     Number of Survivors  Number of Females  Number of Males  \
# 20                    0                  0                0
#
#     Number of Children    Cause of Death Migration route Location of death  \
# 20                   0  Mixed or unknown             NaN   Mexico (likely)
#
#                                    Information Source        Coordinates  \
# 20  Permanent Mission of el Salvador to the UN in ...  19.1452, -101.074
#
#    UNSD Geographical Grouping
# 20            Central America

# %% [markdown]
# Podemos obtener la frecuencia de casos por pais dentro de la region, usando el modulo Counter(). Existe una alternativa mas amigable con groupBy, pero usando reduce y Counter(), se veria asi.

# %%
from collections import Counter
region_counts = reduce(lambda x, y: x.update([y]) or x, central_america_incidents['Country of Origin'], Counter())
pd.DataFrame(region_counts.most_common(10), columns=['Pais', 'Incidentes'])
# Out:
#                         Pais  Incidentes
# 0                     Mexico         705
# 1                   Honduras         307
# 2                  Guatemala         296
# 3                El Salvador         132
# 4                  Nicaragua          62
# 5                    Unknown          29
# 6         Guatemala,Honduras           4
# 7  Guatemala,Honduras,Mexico           3
# 8         El Salvador,Mexico           3
# 9            Honduras,Mexico           2

# %% [markdown]
# Para aprender a usar el modulo Counter de Python recomiendo este tutorial: https://realpython.com/python-counter/ o, ver la documentacion oficial https://docs.python.org/es/3.8/library/collections.html#collections.Counter

# %% [markdown]
# # Ejercicios propuestos
#
# - Usar la funcion map() para crear una columna nueva en base al mes, que de el numero del mes (January es 1, February es 2, etc...)
# - Crear un filtro con la funcion filter() que tome unicamente los incidentes donde hubo violencia
# - Usar reduce() para obtener todos los fallecidos en casos de violencia
